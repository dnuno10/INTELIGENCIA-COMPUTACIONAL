# %%
import pandas as pd
import joblib


loaded_model = joblib.load("/Users/dnuno/Documents/INTELIGENCIA-COMPUTACIONAL/EXPORT-MODEL/ENTRENAMIENTO/car_price_model.joblib")

sample = pd.DataFrame([{
    "Manufacture_Year": 2020,
    "Engine_CC": 2000,
    "Horsepower": 150,
    "Mileage_km_per_l": 14.5,
    "Brand": "Toyota",
    "Body_Type": "SUV",
    "Fuel_Type": "Petrol",
    "Transmission": "Automatic"
}])

pred = loaded_model.predict(sample)[0]
print("Predicción Price_USD:", pred)
# Out:
# Predicción Price_USD: 57969.23049587677
